# %%
import subprocess
import timeit
import os
import time
import math
import random
from memory_profiler import memory_usage
from guppy import hpy; h=hpy()

# %%
class hill_climb:
    
    class climber:
        
        def __init__(self):
            
            self.combo = self.make_rand_position()
            
            self.fitness = 0
            self.n_evals = 0

        def evaluate(self, combo):

            f=open('input.txt','w+')
            for item in combo:
                f.write(str(item)+'\n')
                
            f.close()

            os.system('./cpp_eval')
            
            f = open('fitness_out.txt', 'r')
            fitness = f.read()
            f.close()
            
            self.n_evals = self.n_evals + 1
            
            print('fit',fitness)
            return fitness

        def make_rand_position(self):
            rand_position = [0]*150
            for i in range(0,150):
                rand_position[i] = str(int(random.random() > 0.5))
            return rand_position

        def iterative_solver( self, init_position, n_iterations):
            best_known_fitness = 0
            new_position = init_position.copy()
            previous_position = init_position.copy()
            best_known_fitness = self.evaluate(init_position)
            
            for iterations in range(n_iterations):
                previous_position = new_position.copy()
                
                for key in list(range(150)):

                    candidate_position = new_position.copy()
                    candidate_position[key] = int(not int(new_position[key]))
                    
                    candidate_fitness = self.evaluate(candidate_position)

                    if int(candidate_fitness) > int(best_known_fitness):
                        #print(candidate_fitness)
                        if candidate_fitness == 150:
                            print('solved')
                            return candidate_fitness

                        new_position = candidate_position.copy()
                        best_known_fitness = candidate_fitness
                        
            return best_known_fitness

# %%
solution = []

# %%
my_climber = hill_climb.climber()
    
n_trials = 10

for i in range(n_trials):
    
    init_pos = my_climber.make_rand_position()
    solution.append(my_climber.iterative_solver(init_pos, 4))
    print('foo')
    print(h.heap())
# Out:
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# foo
# Partition of a set of 282312 objects. Total size = 33647175 bytes.
#  Index  Count   %     Size   % Cumulative  % Kind (class / dict of class)
#      0  78770  28  8461716  25   8461716  25 str
#      1  81522  29  6112856  18  14574572  43 tuple
#      2  34518  12  2554394   8  17128966  51 bytes
#      3  17333   6  2506832   7  19635798  58 types.CodeType
#      4  16630   6  2261680   7  21897478  65 function
#      5   2282   1  2200352   7  24097830  72 type
#      6   5020   2  1946456   6  26044286  77 dict (no owner)
#      7    818   0  1159432   3  27203718  81 dict of module
#      8   2282   1  1070408   3  28274126  84 dict of type
#      9   2149   1   665184   2  28939310  86 set
# <799 more rows. Type e.g. '_.more' to view.>
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# foo
# Partition of a set of 282320 objects. Total size = 33647867 bytes.
#  Index  Count   %     Size   % Cumulative  % Kind (class / dict of class)
#      0  78771  28  8461768  25   8461768  25 str
#      1  81523  29  6112912  18  14574680  43 tuple
#      2  34518  12  2554394   8  17129074  51 bytes
#      3  17333   6  2506832   7  19635906  58 types.CodeType
#      4  16630   6  2261680   7  21897586  65 function
#      5   2282   1  2200352   7  24097938  72 type
#      6   5021   2  1946696   6  26044634  77 dict (no owner)
#      7    818   0  1159432   3  27204066  81 dict of module
#      8   2282   1  1070408   3  28274474  84 dict of type
#      9   2149   1   665184   2  28939658  86 set
# <800 more rows. Type e.g. '_.more' to view.>
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# foo
# Partition of a set of 282321 objects. Total size = 33647919 bytes.
#  Index  Count   %     Size   % Cumulative  % Kind (class / dict of class)
#      0  78772  28  8461820  25   8461820  25 str
#      1  81523  29  6112912  18  14574732  43 tuple
#      2  34518  12  2554394   8  17129126  51 bytes
#      3  17333   6  2506832   7  19635958  58 types.CodeType
#      4  16630   6  2261680   7  21897638  65 function
#      5   2282   1  2200352   7  24097990  72 type
#      6   5021   2  1946696   6  26044686  77 dict (no owner)
#      7    818   0  1159432   3  27204118  81 dict of module
#      8   2282   1  1070408   3  28274526  84 dict of type
#      9   2149   1   665184   2  28939710  86 set
# <800 more rows. Type e.g. '_.more' to view.>
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# foo
# Partition of a set of 282336 objects. Total size = 33649745 bytes.
#  Index  Count   %     Size   % Cumulative  % Kind (class / dict of class)
#      0  78773  28  8461872  25   8461872  25 str
#      1  81526  29  6113096  18  14574968  43 tuple
#      2  34523  12  2555208   8  17130176  51 bytes
#      3  17333   6  2506832   7  19637008  58 types.CodeType
#      4  16632   6  2261952   7  21898960  65 function
#      5   2282   1  2200352   7  24099312  72 type
#      6   5022   2  1946936   6  26046248  77 dict (no owner)
#      7    818   0  1159432   3  27205680  81 dict of module
#      8   2282   1  1070408   3  28276088  84 dict of type
#      9   2149   1   665184   2  28941272  86 set
# <799 more rows. Type e.g. '_.more' to view.>
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 34
#
# fit 33
#
# fit 33
#
# fit 33
#
# fit 33
#
# fit 32
#
# fit 32
#
# fit 34
#
# fit 32
#
# fit 34
#
# fit 30
#
# fit 34
#
# fit 32
#
# fit 34
#
# fit 34
#
# fit 30
#
# fit 34
#
# fit 34
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 34
#
# fit 32
#
# fit 34
#
# fit 32
#
# fit 34
#
# fit 34
#
# fit 34
#
# fit 34
#
# fit 34
#
# fit 32
#
# fit 34
#
# fit 32
#
# fit 34
#
# fit 32
#
# fit 34
#
# fit 30
#
# fit 34
#
# fit 34
#
# fit 30
#
# fit 34
#
# fit 34
#
# fit 30
#
# fit 36
#
# fit 32
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 34
#
# fit 32
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 32
#
# fit 34
#
# fit 36
#
# fit 36
#
# fit 32
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 32
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 28
#
# fit 36
#
# fit 32
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 36
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 40
#
# fit 32
#
# fit 40
#
# fit 32
#
# fit 40
#
# fit 32
#
# fit 40
#
# fit 32
#
# fit 40
#
# fit 32
#
# fit 40
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 28
#
# fit 44
#
# fit 44
#
# fit 44
#
# fit 32
#
# fit 36
#
# fit 36
#
# fit 44
#
# fit 44
#
# fit 32
#
# fit 44
#
# fit 36
#
# fit 44
#
# fit 36
#
# fit 24
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 32
#
# fit 40
#
# fit 40
#
# fit 48
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 44
#
# fit 40
#
# fit 28
#
# fit 32
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 44
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 48
#
# fit 40
#
# fit 36
#
# fit 40
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 36
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 36
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 40
#
# fit 48
#
# fit 40
#
# fit 48
#
# fit 40
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 32
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 32
#
# fit 40
#
# fit 36
#
# fit 44
#
# fit 36
#
# fit 44
#
# fit 40
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 28
#
# fit 44
#
# fit 44
#
# fit 44
#
# fit 32
#
# fit 36
#
# fit 36
#
# fit 44
#
# fit 44
#
# fit 32
#
# fit 44
#
# fit 36
#
# fit 44
#
# fit 36
#
# fit 24
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 32
#
# fit 40
#
# fit 40
#
# fit 48
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 44
#
# fit 40
#
# fit 28
#
# fit 32
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
# fit 32
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 44
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 48
#
# fit 40
#
# fit 36
#
# fit 40
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 36
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 36
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 40
#
# fit 48
#
# fit 40
#
# fit 48
#
# fit 40
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 32
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 32
#
# fit 40
#
# fit 36
#
# fit 44
#
# fit 36
#
# fit 44
#
# fit 40
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 28
#
# fit 44
#
# fit 44
#
# fit 44
#
# fit 32
#
# fit 36
#
# fit 36
#
# fit 44
#
# fit 44
#
# fit 32
#
# fit 44
#
# fit 36
#
# fit 44
#
# fit 36
#
# fit 24
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 32
#
# fit 40
#
# fit 40
#
# fit 48
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 44
#
# fit 40
#
# fit 28
#
# fit 32
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 44
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 48
#
# fit 40
#
# fit 36
#
# fit 40
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 36
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 36
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 40
#
# fit 48
#
# fit 40
#
# fit 48
#
# fit 40
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 40
#
# fit 32
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 32
#
# fit 40
#
# fit 36
#
# fit 44
#
# fit 36
#
# fit 44
#
# fit 40
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# foo
# Partition of a set of 282317 objects. Total size = 33647443 bytes.
#  Index  Count   %     Size   % Cumulative  % Kind (class / dict of class)
#      0  78774  28  8461924  25   8461924  25 str
#      1  81522  29  6112856  18  14574780  43 tuple
#      2  34518  12  2554394   8  17129174  51 bytes
#      3  17333   6  2506832   7  19636006  58 types.CodeType
#      4  16630   6  2261680   7  21897686  65 function
#      5   2282   1  2200352   7  24098038  72 type
#      6   5020   2  1946456   6  26044494  77 dict (no owner)
#      7    818   0  1159432   3  27203926  81 dict of module
#      8   2282   1  1070408   3  28274334  84 dict of type
#      9   2149   1   665184   2  28939518  86 set
# <799 more rows. Type e.g. '_.more' to view.>
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# foo
# Partition of a set of 282325 objects. Total size = 33648135 bytes.
#  Index  Count   %     Size   % Cumulative  % Kind (class / dict of class)
#      0  78775  28  8461976  25   8461976  25 str
#      1  81523  29  6112912  18  14574888  43 tuple
#      2  34518  12  2554394   8  17129282  51 bytes
#      3  17333   6  2506832   7  19636114  58 types.CodeType
#      4  16630   6  2261680   7  21897794  65 function
#      5   2282   1  2200352   7  24098146  72 type
#      6   5021   2  1946696   6  26044842  77 dict (no owner)
#      7    818   0  1159432   3  27204274  81 dict of module
#      8   2282   1  1070408   3  28274682  84 dict of type
#      9   2149   1   665184   2  28939866  86 set
# <800 more rows. Type e.g. '_.more' to view.>
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 33
# fit 30
#
# fit 33
#
# fit 35
#
# fit 34
#
# fit 35
#
# fit 32
#
# fit 35
#
# fit 32
#
# fit 32
#
# fit 38
#
# fit 35
#
# fit 35
#
# fit 35
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 38
#
# fit 38
#
# fit 38
#
# fit 38
#
# fit 38
#
# fit 28
#
# fit 36
#
# fit 28
#
# fit 37
#
# fit 38
#
# fit 33
#
# fit 38
#
# fit 38
#
# fit 32
#
# fit 32
#
# fit 38
#
# fit 38
#
# fit 32
#
# fit 38
#
# fit 38
#
# fit 38
#
# fit 38
#
# fit 38
#
# fit 32
#
# fit 44
#
# fit 38
#
# fit 38
#
# fit 32
#
# fit 44
#
# fit 32
#
# fit 44
#
# fit 32
#
# fit 44
#
# fit 32
#
# fit 32
#
# fit 56
#
# fit 44
#
# fit 32
#
# fit 56
#
# fit 56
#
# fit 56
#
# fit 56
#
# fit 56
#
# fit 56
#
# fit 56
#
# fit 56
#
# fit 56
#
# fit 56
#
# fit 48
#
# fit 40
#
# fit 48
#
# fit 40
#
# fit 32
#
# fit 64
#
# fit 40
#
# fit 56
#
# fit 40
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 32
#
# fit 48
#
# fit 64
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 32
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 64
#
# fit 32
#
# fit 64
#
# fit 32
#
# fit 32
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 16
#
# fit 48
#
# fit 32
#
# fit 60
#
# fit 60
#
# fit 52
#
# fit 52
#
# fit 64
#
# fit 32
#
# fit 32
#
# fit 64
#
# fit 64
#
# fit 32
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 64
#
# fit 32
#
# fit 64
#
# fit 32
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 56
#
# fit 40
#
# fit 56
#
# fit 40
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 32
#
# fit 48
#
# fit 64
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 32
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 64
#
# fit 32
#
# fit 64
#
# fit 32
#
# fit 32
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 16
#
# fit 48
#
# fit 32
#
# fit 60
#
# fit 60
#
# fit 52
#
# fit 52
#
# fit 64
#
# fit 32
#
# fit 32
#
# fit 64
#
# fit 64
#
# fit 32
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 64
#
# fit 32
#
# fit 64
#
# fit 32
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 56
#
# fit 40
#
# fit 56
#
# fit 40
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 32
#
# fit 48
#
# fit 64
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 32
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 64
#
# fit 32
#
# fit 64
#
# fit 32
#
# fit 32
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 16
#
# fit 48
#
# fit 32
#
# fit 60
#
# fit 60
#
# fit 52
#
# fit 52
#
# fit 64
#
# fit 32
#
# fit 32
#
# fit 64
#
# fit 64
#
# fit 32
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 64
#
# fit 32
#
# fit 64
#
# fit 32
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 56
#
# fit 40
#
# fit 56
#
# fit 40
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 48
#
# fit 32
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 48
#
# fit 48
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# fit 64
#
# foo
# Partition of a set of 282319 objects. Total size = 33647547 bytes.
#  Index  Count   %     Size   % Cumulative  % Kind (class / dict of class)
#      0  78776  28  8462028  25   8462028  25 str
#      1  81522  29  6112856  18  14574884  43 tuple
#      2  34518  12  2554394   8  17129278  51 bytes
#      3  17333   6  2506832   7  19636110  58 types.CodeType
#      4  16630   6  2261680   7  21897790  65 function
#      5   2282   1  2200352   7  24098142  72 type
#      6   5020   2  1946456   6  26044598  77 dict (no owner)
#      7    818   0  1159432   3  27204030  81 dict of module
#      8   2282   1  1070408   3  28274438  84 dict of type
#      9   2149   1   665184   2  28939622  86 set
# <799 more rows. Type e.g. '_.more' to view.>
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# foo
# Partition of a set of 282327 objects. Total size = 33648303 bytes.
#  Index  Count   %     Size   % Cumulative  % Kind (class / dict of class)
#      0  78777  28  8462080  25   8462080  25 str
#      1  81523  29  6112912  18  14574992  43 tuple
#      2  34518  12  2554394   8  17129386  51 bytes
#      3  17333   6  2506832   7  19636218  58 types.CodeType
#      4  16630   6  2261680   7  21897898  65 function
#      5   2282   1  2200352   7  24098250  72 type
#      6   5021   2  1946696   6  26044946  77 dict (no owner)
#      7    818   0  1159432   3  27204378  81 dict of module
#      8   2282   1  1070408   3  28274786  84 dict of type
#      9   2149   1   665184   2  28939970  86 set
# <800 more rows. Type e.g. '_.more' to view.>
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# foo
# Partition of a set of 282328 objects. Total size = 33648355 bytes.
#  Index  Count   %     Size   % Cumulative  % Kind (class / dict of class)
#      0  78778  28  8462132  25   8462132  25 str
#      1  81523  29  6112912  18  14575044  43 tuple
#      2  34518  12  2554394   8  17129438  51 bytes
#      3  17333   6  2506832   7  19636270  58 types.CodeType
#      4  16630   6  2261680   7  21897950  65 function
#      5   2282   1  2200352   7  24098302  72 type
#      6   5021   2  1946696   6  26044998  77 dict (no owner)
#      7    818   0  1159432   3  27204430  81 dict of module
#      8   2282   1  1070408   3  28274838  84 dict of type
#      9   2149   1   665184   2  28940022  86 set
# <800 more rows. Type e.g. '_.more' to view.>
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# fit 32
#
# foo
# Partition of a set of 282322 objects. Total size = 33647767 bytes.
#  Index  Count   %     Size   % Cumulative  % Kind (class / dict of class)
#      0  78779  28  8462184  25   8462184  25 str
#      1  81522  29  6112856  18  14575040  43 tuple
#      2  34518  12  2554394   8  17129434  51 bytes
#      3  17333   6  2506832   7  19636266  58 types.CodeType
#      4  16630   6  2261680   7  21897946  65 function
#      5   2282   1  2200352   7  24098298  72 type
#      6   5020   2  1946456   6  26044754  77 dict (no owner)
#      7    818   0  1159432   3  27204186  81 dict of module
#      8   2282   1  1070408   3  28274594  84 dict of type
#      9   2149   1   665184   2  28939778  86 set
# <799 more rows. Type e.g. '_.more' to view.>

# %%
for i in range(n_trials):
    print(solution[i])
# Out:
# 32
#
# 32
#
# 32
#
# 32
#
# 32
#
# 48
#
# 32
#
# 64
#
# 32
#
# 32

# %%
print('Evaluations per solution = ' ,my_climber.n_evals/n_trials)
# Out:
# Evaluations per solution =  601.0

# %%
print
# Out:
# <function print>
